# %%
from pathlib import Path
from pyspark.sql import SparkSession
from pyspark.sql.functions import broadcast, col, concat_ws, lit, when
# Start Spark

"""
TODO: read from hadoop, draw some graph show the dataset

"""
"""
read in csv, use dictionary to explain values, left join 2 csvs.
"""
spark = SparkSession.builder \
    .appName("football-events-pipeline") \
    .getOrCreate()

events_path = str("events.csv")
ginf_path   = str( "ginf.csv")

events = spark.read.option("header", True).option("inferSchema", True).csv(events_path)
ginf   = spark.read.option("header", True).option("inferSchema", True).csv(ginf_path)

df = events.alias("e").join(ginf.alias("g"), on="id_odsp", how="left")
print("Joined df cols:", df.columns)

DICT_SCHEMA = "code INT, label STRING"

def read_dict(name: str):
    path = str(f"{name}.txt")
    return spark.read.option("sep", "\t").schema(DICT_SCHEMA).csv(path)

dict_event_type   = read_dict("event_type")
dict_event_type2  = read_dict("event_type2")
dict_shot_place   = read_dict("shot_place")
dict_shot_outcome = read_dict("shot_outcome")
dict_location     = read_dict("location")


def replace_with_dict(df_in, col_name, dict_df):
    if col_name not in df_in.columns:
        print(f"[skip] {col_name} not in dataframe")
        return df_in

    d = broadcast(
        dict_df.select(
            col("code").cast("string").alias(col_name),
            col("label").alias(f"{col_name}__label")
        )
    )

    out = (
        df_in.withColumn(col_name, col(col_name).cast("string"))
            .join(d, on=col_name, how="left")
            .withColumn(
                col_name,
                when(col(f"{col_name}__label").isNotNull(), col(f"{col_name}__label"))
                .otherwise(col(col_name))
            )
            .drop(f"{col_name}__label")
    )
    return out

cols_to_replace = {
    "event_type":   dict_event_type,
    "event_type2":  dict_event_type2,
    "shot_place":   dict_shot_place,
    "shot_outcome": dict_shot_outcome,
    "location":     dict_location
}

for c, ddf in cols_to_replace.items():
    df = replace_with_dict(df, c, ddf)

# df.select("id_odsp", "event_type", "event_type2", "shot_place", "shot_outcome", "location").show(5, truncate=False)     # For unknow reason, this line will cause the lost of event_type2
# Out:
# Joined df cols: ['id_odsp', 'id_event', 'sort_order', 'time', 'text', 'event_type', 'event_type2', 'side', 'event_team', 'opponent', 'player', 'player2', 'player_in', 'player_out', 'shot_place', 'shot_outcome', 'is_goal', 'location', 'bodypart', 'assist_method', 'situation', 'fast_break', 'link_odsp', 'adv_stats', 'date', 'league', 'season', 'country', 'ht', 'at', 'fthg', 'ftag', 'odd_h', 'odd_d', 'odd_a', 'odd_over', 'odd_under', 'odd_bts', 'odd_bts_n']

# %%
from pyspark.sql import functions as F

# 1) Keep only these columns
KEEP_COLS = [
    "id_odsp","sort_order","time","event_type","event_type2","event_team","player","player2",
    "shot_place","shot_outcome","is_goal","location","bodypart","date","league",
    "season","country","ht","at"
]
present = [c for c in KEEP_COLS if c in df.columns]
missing = [c for c in KEEP_COLS if c not in df.columns]
if missing:
    print("[warn] missing columns:", missing)

df = df.select(*present)

# Split into per-event fields and match-level metadata
EVENT_FIELDS = [
    "sort_order","time","event_type","event_type2","event_team","player","player2",
    "shot_place","shot_outcome","is_goal","location","bodypart"
]
MATCH_META = ["id_odsp","date","league","season","country","ht","at"]

present_event = [c for c in EVENT_FIELDS if c in df.columns]
present_meta  = [c for c in MATCH_META if c in df.columns]

# 2) One formatted line per event (easier to read in RAG)
event_line = F.concat_ws(
    " | ",
    *[F.concat_ws(": ", F.lit(c), F.col(c).cast("string")) for c in present_event if c not in ("sort_order","time")]
).alias("event_line_body")

# Include time/sort_order at the start for readability
prefix = F.concat_ws(
    " | ",
    *([F.concat_ws(": ", F.lit("time"), F.col("time").cast("string"))] if "time" in present_event else []),
    *([F.concat_ws(": ", F.lit("sort_order"), F.col("sort_order").cast("string"))] if "sort_order" in present_event else [])
).alias("event_prefix")

per_event = (
    df
    .select(*(present_meta + ["id_odsp"]), *present_event)
    .withColumn("event_prefix", prefix)
    .withColumn("event_line_body", event_line)
    .withColumn(
        "event_line_full",
        F.when(F.col("event_prefix").isNotNull() & (F.col("event_prefix") != ""),
               F.concat_ws(" | ", F.col("event_prefix"), F.col("event_line_body")))
         .otherwise(F.col("event_line_body"))
    )
)

# Choose ordering column: prefer sort_order, else time, else 0
order_col = (
    F.when(F.col("sort_order").isNotNull(), F.col("sort_order").cast("long"))
     .when(F.col("time").isNotNull(), F.col("time").cast("double"))
     .otherwise(F.lit(0).cast("double"))
).alias("ord")

per_event = per_event.withColumn("ord", order_col)

# 3) Aggregate rows -> one chunk per id_odsp, preserving order
agg = (
    per_event
    .groupBy("id_odsp", *[c for c in present_meta if c != "id_odsp"])
    .agg(F.sort_array(F.collect_list(F.struct(F.col("ord"), F.col("event_line_full")))).alias("events"))
    .withColumn("text", F.concat_ws("\n", F.transform("events", lambda x: x["event_line_full"])))
    .drop("events")
)

# Result: one row per match, with a single RAG-ready text chunk
rag_matches = agg.select("id_odsp", "text", *[c for c in present_meta if c != "id_odsp"])

# Quick sanity check
print("Match docs:", rag_matches.count())
rag_matches.select("id_odsp", "text").show(2, truncate=False)

pdf = rag_matches.toPandas()  # typically ~your ginf size
from langchain_core.documents import Document
import pandas as pd

meta_keys = [c for c in ["id_odsp","date","league","season","country","ht","at"] if c in pdf.columns]
docs = []
for _, row in pdf.iterrows():
    meta = {k: (None if (isinstance(row[k], float) and pd.isna(row[k])) else str(row[k])) for k in meta_keys}
    docs.append(Document(page_content=row["text"], metadata=meta))
# Out:
# Match docs: 9074
# +---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |id_odsp  |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |04tOFUYO/|time: 1 | sort_order: 1 | event_type: Free kick won | event_type2: NA | event_team: Udinese | player: emmanuel badu | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 1 | sort_order: 2 | event_type: Foul | event_type2: NA | event_team: AC Milan | player: mbaye niang | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 2 | sort_order: 3 | event_type: Free kick won | event_type2: NA | event_team: AC Milan | player: andrea bertolacci | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Attacking half | bodypart: NA\ntime: 2 | sort_order: 4 | event_type: Foul | event_type2: NA | event_team: Udinese | player: emmanuel badu | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 4 | sort_order: 5 | event_type: Attempt | event_type2: Key Pass | event_team: Udinese | player: zdravko kuzmanovic | player2: ryder matos | shot_place: Misses to the right | shot_outcome: Off target | is_goal: 0 | location: Outside the box | bodypart: 1\ntime: 6 | sort_order: 6 | event_type: Free kick won | event_type2: NA | event_team: AC Milan | player: andrea bertolacci | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Attacking half | bodypart: NA\ntime: 6 | sort_order: 7 | event_type: Foul | event_type2: NA | event_team: Udinese | player: francesco lodi | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 7 | sort_order: 8 | event_type: Foul | event_type2: NA | event_team: AC Milan | player: alex | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 7 | sort_order: 9 | event_type: Free kick won | event_type2: NA | event_team: Udinese | player: molla wague | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 8 | sort_order: 10 | event_type: Attempt | event_type2: NA | event_team: Udinese | player: francesco lodi | player2: NA | shot_place: Blocked | shot_outcome: Blocked | is_goal: 0 | location: Outside the box | bodypart: 2\ntime: 9 | sort_order: 11 | event_type: Free kick won | event_type2: NA | event_team: Udinese | player: danilo | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 9 | sort_order: 12 | event_type: Foul | event_type2: NA | event_team: AC Milan | player: mbaye niang | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 9 | sort_order: 13 | event_type: Free kick won | event_type2: NA | event_team: Udinese | player: francesco lodi | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Attacking half | bodypart: NA\ntime: 12 | sort_order: 14 | event_type: Corner | event_type2: NA | event_team: AC Milan | player: molla wagua© | player2: molla wagua© | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 13 | sort_order: 15 | event_type: Attempt | event_type2: Key Pass | event_team: AC Milan | player: mbaye niang | player2: luca antonelli | shot_place: Blocked | shot_outcome: Blocked | is_goal: 0 | location: Left side of the box | bodypart: 1\ntime: 14 | sort_order: 16 | event_type: Offside | event_type2: Failed through ball | event_team: AC Milan | player: carlos bacca | player2: alex | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 15 | sort_order: 17 | event_type: Corner | event_type2: NA | event_team: AC Milan | player: felipe | player2: felipe | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 15 | sort_order: 18 | event_type: Offside | event_type2: Failed through ball | event_team: Udinese | player: ryder matos | player2: cyril thereau | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 17 | sort_order: 19 | event_type: At ...
# |0E56wcFm/|time: 3 | sort_order: 1 | event_type: Foul | event_type2: NA | event_team: Bastia | player: ryad boudebouz | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 3 | sort_order: 2 | event_type: Free kick won | event_type2: NA | event_team: Lyon | player: yassine benzia | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 5 | sort_order: 3 | event_type: Foul | event_type2: NA | event_team: Bastia | player: julian palmieri | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 7 | sort_order: 4 | event_type: Foul | event_type2: NA | event_team: Lyon | player: alexandre lacazette | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 7 | sort_order: 5 | event_type: Free kick won | event_type2: NA | event_team: Bastia | player: francois modesto | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 10 | sort_order: 6 | event_type: Attempt | event_type2: Key Pass | event_team: Bastia | player: florian raspentino | player2: romaric | shot_place: Centre of the goal | shot_outcome: On target | is_goal: 0 | location: Centre of the box | bodypart: 1\ntime: 11 | sort_order: 7 | event_type: Corner | event_type2: NA | event_team: Lyon | player: julian palmieri | player2: julian palmieri | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 12 | sort_order: 8 | event_type: Free kick won | event_type2: NA | event_team: Bastia | player: florian raspentino | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 12 | sort_order: 9 | event_type: Foul | event_type2: NA | event_team: Lyon | player: alexandre lacazette | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 13 | sort_order: 10 | event_type: Foul | event_type2: NA | event_team: Bastia | player: yannick cahuzac | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 13 | sort_order: 11 | event_type: Free kick won | event_type2: NA | event_team: Lyon | player: gueida fofana | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Attacking half | bodypart: NA\ntime: 20 | sort_order: 12 | event_type: Attempt | event_type2: NA | event_team: Bastia | player: milos krasic | player2: NA | shot_place: Misses to the left | shot_outcome: Off target | is_goal: 0 | location: Right side of the box | bodypart: 1\ntime: 24 | sort_order: 13 | event_type: Free kick won | event_type2: NA | event_team: Bastia | player: adama ba | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Defensive half | bodypart: NA\ntime: 24 | sort_order: 14 | event_type: Foul | event_type2: NA | event_team: Lyon | player: jordan ferri | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 25 | sort_order: 15 | event_type: Attempt | event_type2: Key Pass | event_team: Lyon | player: yassine benzia | player2: alexandre lacazette | shot_place: Misses to the right | shot_outcome: Off target | is_goal: 0 | location: Left side of the box | bodypart: 2\ntime: 27 | sort_order: 16 | event_type: Foul | event_type2: NA | event_team: Lyon | player: alexandre lacazette | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: NA | bodypart: NA\ntime: 27 | sort_order: 17 | event_type: Free kick won | event_type2: NA | event_team: Bastia | player: romaric | player2: NA | shot_place: NA | shot_outcome: NA | is_goal: 0 | location: Attacking half | bodypart: NA\ntime: 31 | sort_order: 18 | event_type: Attempt | event_type2: Key Pass | event_team: Lyon | player: henri bedimo | player2: clement grenier | shot_place: Misses to the right | shot_outcome: Off target | is_goal: 0 | location: Outside the box | bodypart ...
# +---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 2 rows

# %%
# Spark -> JSON String -> Python write JSONL
from pyspark.sql.functions import col, concat_ws, lit

def _ensure_cols(df, cols):
    for c in cols:
        if c not in df.columns:
            df = df.withColumn(c, lit(""))
    return df

need_cols = ["id_odsp","event_team","season","shot_outcome","location","event_type","event_type2","player"]
df = _ensure_cols(df, need_cols)

TEXT_COL = concat_ws(" | ",
    lit("id_odsp="), col("id_odsp"),
    lit("team="), col("event_team"),
    lit("season="), col("season"),
    lit("type="), col("event_type"),
    lit("type2="), col("event_type2"),
    lit("shot="), col("shot_outcome"),
    lit("location="), col("location"),
    lit("player="), col("player")
).alias("text")

# %%
sel = df.select(
    col("id_odsp"), col("event_team"), col("season"), col("shot_outcome"), col("location"), col("event_type"), col("event_type2"), col("player"), TEXT_COL
)

# MAX_ROWS = None  
json_rows = sel.toJSON().collect()   
print(json_rows)

# Write to JSONL（each line is a JSON）
OUT_JSONL = "rag_events.jsonl"
with open(OUT_JSONL, "w", encoding="utf-8") as f:
    for line in json_rows:
        print(line)
        # f.write(line + "\n")

print(f"Wrote JSONL: {OUT_JSONL}, rows: {len(json_rows)}")

# %%
df.count()
