# %% [markdown]
# ## 1. Load from vectorDb (Chroma)

# %%
from langchain_community.vectorstores import Chroma
from openai import OpenAI
from langchain_core.embeddings import Embeddings
import os, chromadb
from dotenv import load_dotenv

load_dotenv()  
alikey = os.getenv("DASHSCOPE_API_KEY")

# === Ali embedding ===
class TextV4Embeddings(Embeddings):
    def __init__(self, api_key, base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"):
        self.client = OpenAI(api_key=alikey, base_url=base_url)
        self.model = "text-embedding-v4"
    def embed_documents(self, texts): 
        resp = self.client.embeddings.create(model=self.model, input=texts, dimensions=1024)
        return [d.embedding for d in resp.data]
    def embed_query(self, text):
        return self.embed_documents([text])[0]

# === initialize embedding model ===
emb = TextV4Embeddings(api_key=alikey)

CHROMA_DIR = "chroma_football_events"

# === list all collections ===
client = chromadb.PersistentClient(path=CHROMA_DIR)
collections = client.list_collections()

if not collections:
    raise RuntimeError(f"No collection in database，check if the path is right: {CHROMA_DIR}")

print(f"find {len(collections)} collections：")
for c in collections:
    print(" -", c.name)

dbs = {}
for c in collections:
    name = c.name
    dbs[name] = Chroma(
        collection_name=name,
        persist_directory=CHROMA_DIR,
        embedding_function=emb,
    )
    print(f" load success: {name} | doc count: {dbs[name]._collection.count()}")

vectordb = dbs.get("football_events") or list(dbs.values())[0]
print(f"\n default collection: {vectordb._collection.name} | doc count: {vectordb._collection.count()}")
# Out:
# find 1 collections：
#  - football_events
#  load success: football_events | doc count: 940822
#
#  default collection: football_events | doc count: 940822

# %% [markdown]
# ## 2. Rank Fusion

# %% [markdown]
# #### 2.1 Data preparing

# %%
# !pip install rank_bm25
from rank_bm25 import BM25Okapi
from langchain_core.documents import Document
import re
import pandas as pd

# Load data from chromaDB
data = vectordb._collection.get(include=["documents", "metadatas"])

# Turn into DataFrame
texts = data["documents"]
meta_df = pd.DataFrame(data["metadatas"])
pdf = pd.concat([pd.DataFrame({"text": texts}), meta_df], axis=1)

print(f"Loaded {len(pdf)} records from collection '{vectordb._collection.name}' for BM25 index.")

def tokenize(t): return re.findall(r"[A-Za-z0-9_]+", str(t).lower())

corpus_tokens = [tokenize(t) for t in pdf["text"].tolist()]
bm25 = BM25Okapi(corpus_tokens)
id_list = pdf["id_odsp"].tolist()
# Out:
# Requirement already satisfied: rank_bm25 in f:\project\football-match-qa-system\football-match-qa-system\.venv\lib\site-packages (0.2.2)
# Requirement already satisfied: numpy in f:\project\football-match-qa-system\football-match-qa-system\.venv\lib\site-packages (from rank_bm25) (1.26.4)
# Loaded 940822 records from collection 'football_events' for BM25 index.

# %% [markdown]
# #### 2.2 Ranking stradegy
# - Both BM25 and Vector Search use document as the main searchable text.
# - Vector Search can additionally use metadata as a filter to narrow down the search space.

# %%
def bm25_retrieve(query, k=50):
    scores = bm25.get_scores(tokenize(query))
    top_idx = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:k]
    docs = []
    for i in top_idx:
        row = pdf.iloc[i]
        docs.append((
            Document(page_content=row["text"], metadata=row.to_dict()),
            float(scores[i])
        ))
    return docs

def rrf_fuse(results_a, results_b, k_base=60, top_n=20):
    ranks = {}
    for lst in [results_a, results_b]:
        for rank, (doc, _) in enumerate(lst, 1):
            key = doc.metadata.get("id_odsp", id(doc))
            ranks.setdefault(key, {"doc": doc, "rrf": 0.0})
            ranks[key]["rrf"] += 1.0 / (k_base + rank)
    fused = sorted(ranks.values(), key=lambda x: x["rrf"], reverse=True)[:top_n]
    return [(x["doc"], x["rrf"]) for x in fused]

def hybrid_retrieve(question, k_vec=12, k_bm25=50, top_n=12):
    vec = vectordb.similarity_search_with_score(question, k=k_vec)     
    bm  = bm25_retrieve(question, k=k_bm25)                           
    return rrf_fuse(vec, bm, k_base=60, top_n=top_n)

def hybrid_retrieve_hyde(hypothesis, question, k_vec=12, k_bm25=50, top_n=12):
    vec = vectordb.similarity_search_with_score(hypothesis, k=k_vec)     
    bm  = bm25_retrieve(question, k=k_bm25)                           
    return rrf_fuse(vec, bm, k_base=60, top_n=top_n)

# %% [markdown]
# #### 2.3 Rerank

# %%
from FlagEmbedding import FlagReranker

reranker = FlagReranker('BAAI/bge-reranker-base', use_fp16=True)

def rerank(question, retrieved):
    # Prepare [query, doc_text] pairs
    pairs = []
    for doc, _ in retrieved:
        pairs.append([question, doc.page_content])

    # Compute scores
    scores = reranker.compute_score(pairs)  # Bigger is better

    # Combine docs and new scores
    doc_score_pairs = []
    for (doc, _), s in zip(retrieved, scores):
        doc_score_pairs.append((doc, float(s)))

    # Sort by score descending
    doc_score_pairs.sort(key=lambda x: x[1], reverse=True)

    return doc_score_pairs

# %% [markdown]
# ## 3. Q&A

# %% [markdown]
# #### 3.1 Preparing LLM

# %%
import os, json, time
from typing import Dict, List, Tuple
from langchain_openai import ChatOpenAI
from langchain.schema import BaseMessage

load_dotenv()  
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = "https://api.deepseek.com"  

llm_chat = ChatOpenAI(
    model="deepseek-chat",
    temperature=0,
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

llm_reasoner = ChatOpenAI(
    model="deepseek-reasoner",
    temperature=0,
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
# print("Using DeepSeek model via OpenAI-compatible API")

chat_history = []

def build_history_text(history, max_turns: int = 6) -> str:
    trimmed = history[-max_turns*2:]    # Each turn = (user + assistant), so we keep max_turns * 2 messages.
    lines = []
    for role, content in trimmed:
        prefix = "user" if role == "user" else "assistant"
        lines.append(f"{prefix}：{content}")
    return "\n".join(lines)

# %% [markdown]
# #### 3.2 Query rewrite

# %%
def need_rewrite(query: str, history_text: str) -> str:
    prompt = f"""
        You are a helpful assistant that decides whether a user's latest question
        needs to be rewritten into a self-contained query for retrieval in a RAG system.

        You will be given:
        1. A short conversation history between the user and the assistant.
        2. The user's latest question.

        Your task:
        - If the latest question is already self-contained and clear enough for retrieval,
          answer "0".
        - If the latest question depends on the previous conversation
          (for example, it contains pronouns, vague references, or omitted context),
          answer "1".
        - If the latest question points to information that is not possible to infer from the previous conversation which means the query is unanswerable
          (for example, it contains pronouns, vague references, or omitted context that can not found in history ),
          answer "2".
      
        Respond with one numer: 0, 1 or 2.
        Do not include any explanation or punctuation.

        ---

        Conversation history:
        {history_text}

        User's query:
        {query}

        Your answer (YES or NO):
    """.strip()

    resp = llm_chat.invoke(prompt)
    decision = resp.content.strip()
    return decision   # "0", "1" or "2"

def rewrite_query(query: str, history_text: str) -> str:
    prompt = f"""
        You are a helpful assistant that rewrites a user's question into a self-contained query
        suitable for retrieval in a RAG system.

        You will be given:
        1. A short conversation history between the user and the assistant.
        2. The user's latest question.

        Your task:
        - Rewrite the latest question to include any necessary context from the conversation history,
          making it clear and self-contained for retrieval.
        - Ensure the rewritten query is concise and focused on the main information need.
        - Avoid adding any new information not present in the conversation.
        - Don't be too long; keep it as brief as possible while still being self-contained.

        ---

        Conversation history:
        {history_text}

        User's query:
        {query}

        Rewritten self-contained query:
    """.strip()

    resp = llm_chat.invoke(prompt)
    return resp.content.strip()

# %% [markdown]
# #### 3.3 HyDE

# %%
def generate_hypothetical_doc(query: str) -> str:
    prompt = f"Write a short factual paragraph that could answer: {query}"
    return llm_chat.invoke(prompt).content

# %% [markdown]
# #### 3.4 Answer Generating

# %%
def answer_with_llm(query: str, k: int = 12, use_history: bool = True, use_hyde: bool = True) -> str:
    # Build history text if enabled
    history_text = ""
    history_text_query = ""
    if use_history and chat_history:
        history_text = build_history_text(chat_history, max_turns=6)
        history_text_query = build_history_text(chat_history, max_turns=3)

    # Determine if rewriting is needed
    decision = need_rewrite(query, history_text_query)

    # If unanswerable, return early
    if decision == "2":
        return "The question is unanswerable with the given context. Please provide more information."
    
    # Rewrite the query
    if decision == "1":
        rewritten = rewrite_query(query, history_text)
    else:
        rewritten = query

    # Generate hypothetical document if enabled
    retrieve_results = []
    if use_hyde:
        hypothesis = generate_hypothetical_doc(rewritten)
        retrieve_results = hybrid_retrieve_hyde(hypothesis, query, k_vec=k, k_bm25=max(30, 3*k), top_n=k)
    else:
        retrieve_results = hybrid_retrieve(query, k_vec=k, k_bm25=max(30, 3*k), top_n=k)
    
    # Rerank documents
    results = rerank(query, retrieve_results)

    # Build context text from retrieved documents
    context_chunks = []
    for idx, doc in enumerate(results):
        text = getattr(doc, "page_content", str(doc))
        context_chunks.append(f"[{idx + 1}] {text}")
    context_text = "\n\n".join(context_chunks)

    # Build the final prompt
    prompt = f"""
                You are a football assistant. 
                
                Instruction:
                - Write a detailed summary, and briefly explain with data.
                - The answer should be well structured.
                
                Previous conversation:
                {history_text if history_text else "(none)"}

                Relevant context:
                {context_text}

                User question:
                {query}

                Your answer:
            """.strip()

    # Call the existing LLM
    resp = llm_reasoner.invoke(prompt)
    answer = resp.content if hasattr(resp, "content") else str(resp)

    # Append this turn to the chat history
    chat_history.append(("user", query))
    chat_history.append(("assistant", answer))

    return answer

# %% [markdown]
# #### 3.5 Interacting with LLM

# %%
# !pip install gradio -q

# %%
import gradio as gr

def chat_fn(message, history):
    answer = answer_with_llm(message)
    history = history + [[message, answer]]
    return "", history

with gr.Blocks() as demo:
    gr.Markdown("## Football Assistant")
    chatbot = gr.Chatbot(height=560, type="messages")
    msg = gr.Textbox(placeholder="Ask me: Analyze the playing style and on-pitch role of Cheikhou Kouyate for West Ham during the 2016 season")
    clear = gr.Button("Clear Conversation")

    msg.submit(chat_fn, [msg, chatbot], [msg, chatbot])
    clear.click(lambda: None, None, chatbot)

demo.launch()

# %% [markdown]
# #### 3.6 Test space

# %%
decision = need_rewrite("Is he a defender?", chat_history)
print("Need rewrite:", decision)
# Out:
# Need rewrite: 1

# %%
rewritten = rewrite_query("Is he a defender?", chat_history)
print("Rewritten query:", rewritten)
# Out:
# Rewritten query: Cheikhou Kouyate's primary playing role and position for West Ham in the 2016 season

# %%
hypothesis = generate_hypothetical_doc("Is Cheikhou Kouyate a defender?")
print("Hypothesis:", hypothesis)
# Out:
# Hypothesis: Cheikhou Kouyaté is primarily a defensive midfielder, but he has also been deployed as a central defender throughout his career. While not exclusively a defender, his versatility and physical attributes have seen him play in both defensive and midfield roles for club and country. Therefore, while he is not solely a defender, he is a player with significant experience and capability in that position.

# %%
print("chat_history:", chat_history)
# Out:
# chat_history: [('user', 'Analyze the playing style and on-pitch role of Cheikhou Kouyate for West Ham during the 2016 season'), ('assistant', 'Of course. Based on the provided event data from the 2016 season, here is a detailed analysis of Cheikhou Kouyate\'s playing style and on-pitch role for West Ham United.\n\n### Analysis of Cheikhou Kouyate for West Ham (2016 Season)\n\nThe data paints a clear picture of Cheikhou Kouyate as a physically imposing, defensively-oriented midfielder who was also a significant aerial threat in the opposition\'s box. His role was that of a dynamic enforcer and a box-to-box presence, albeit with a notable disciplinary record.\n\n---\n\n#### 1. Primary Role: Defensive Midfield Enforcer\n\nKouyate\'s most frequent and statistically significant action was winning free kicks in the defensive half.\n\n*   **Data Point:** The documents show **7 separate instances** of "Cheikhou Kouyate wins a free kick in the defensive half."\n*   **Explanation:** This high frequency indicates a player consistently engaged in physical duels, tackles, and defensive interventions. Winning free kicks in his own half relieves pressure on the defense and allows the team to reorganize. This was a fundamental part of his role, suggesting he was the primary ball-winner and disruptor in midfield.\n\n#### 2. Attacking Threat: Aerial Presence in the Box\n\nDespite his defensive duties, Kouyate was a genuine threat in the opposition\'s penalty area, primarily from set-pieces.\n\n*   **Data Points:**\n    *   **Attempt Saved:** A headed attempt from the centre of the box, saved in the top corner (assisted by Dimitri Payet).\n    *   **Attempt Missed:** A left-footed shot from the centre of the box.\n    *   **Attempt Blocked:** A right-footed shot from the right side of the box.\n*   **Explanation:** All three recorded shooting attempts originate from inside the penalty area, with one being a clear headed chance. This demonstrates his box-to-box capability and his role as a target for crosses, making him a dual-phase player who contributed to both defense and attack.\n\n#### 3. Disciplinary Record: Aggression and its Consequences\n\nA key aspect of Kouyate\'s playing style was his aggressive approach, which occasionally crossed the line.\n\n*   **Data Points:**\n    *   **Red Card:** One instance of being shown a straight red card.\n    *   **Yellow Card:** One instance of being shown a yellow card for a bad foul.\n*   **Explanation:** This disciplinary record is a direct consequence of his combative and physical playing style. While effective in breaking up play (as seen with the free kicks), it also carried a risk, potentially leaving his team at a numerical disadvantage.\n\n### Summary\n\nDuring the 2016 season, **Cheikhou Kouyate operated as a vital, physically dominant central midfielder for West Ham.** His primary function was to break up opposition attacks in the defensive half, a fact overwhelmingly supported by the data on free kicks won. He complemented this defensive base with a dangerous attacking presence, frequently arriving in the box to attempt shots, particularly with his head. However, his aggressive style was a double-edged sword, leading to a significant number of fouls and at least one sending-off. In essence, he was the team\'s engine room enforcer and a sporadic but potent goal-scoring threat.')]

# %%
ans = answer_with_llm(
    "Is Cheikhou Kouyate a defender?",
    k=20
)

print("\n=== Answer ===\n")
print(ans)
# Out:
# === Answer ===
#
# Based on the available data from the 2015-2017 seasons, the answer is nuanced. While Cheikhou Kouyate frequently performed defensive duties, his primary on-pitch role was not that of a traditional defender.
#
# ### Detailed Summary
#
# Cheikhou Kouyate was a **central midfielder** for West Ham United who possessed strong defensive attributes, making him a key part of the team's defensive structure. However, his positioning, actions, and overall role indicate he was a **box-to-box midfielder** rather than a dedicated defender.
#
# Here is a brief explanation supported by the data:
#
# #### 1. Evidence of Defensive Involvement
# The data confirms Kouyate was heavily involved in defensive actions, which might lead to him being perceived as a defender.
# *   **Conceding Corners:** The documents show multiple instances of him conceding corners for the opposition (e.g., against Tottenham and Chelsea in 2016), indicating last-ditch defensive interventions.
# *   **Committing Fouls:** There is a significant record of fouls committed across multiple seasons, with **6 separate foul events documented in the 2015 season alone**. This points to a physically combative style typical of a defensive-minded midfielder.
#
# #### 2. Overwhelming Evidence of a Midfielder's Role
# Despite his defensive work, the data more strongly aligns with the profile of a central midfielder, specifically one with a box-to-box function.
# *   **Attacking Positioning & Threat:** The most frequent event type for Kouyate in the 2016 season is "Attempt." Crucially, the location of these attempts reveals his true positioning:
#     *   **6 out of 7** recorded shot attempts in 2016 came from **inside the penalty area** (Centre of the box, Left side of the box).
#     *   This pattern shows a player whose primary offensive role was to arrive in the box as a goal-scoring threat, not a defender who stays back.
# *   **Offensive Collaborations:** His attempts were consistently assisted by attacking and creative players like **Dimitri Payet (3 assists)** and Mark Noble, highlighting his integration into the team's attacking phases.
#
# ### Conclusion
#
# **No, Cheikhou Kouyate was not a defender.** He was a **defensively robust central midfielder**. His role required him to contribute significantly to both defense and attack, fulfilling the duties of a classic box-to-box player. While he was a tenacious ball-winner and a physical presence in his own half (explaining the fouls and conceded corners), his most common and impactful actions in the final third were those of a midfielder making late runs into the opposition's box.

# %% [markdown]
# ## 4. Dataset Prearing

# %% [markdown]
# #### 4.1 Retrieve Logic

# %%
def retrieve_for_eval(query: str, k: int = 12, use_rewrite: bool = True, use_hyde: bool = True):
    history_text_query = ""

    if use_rewrite:
        decision = need_rewrite(query, history_text_query)

        if decision == "2":
            return []

        if decision == "1":
            rewritten = rewrite_query(query, history_text_query)
        else:
            rewritten = query
    else:
        rewritten = query

    if use_hyde:
        hypothesis = generate_hypothetical_doc(rewritten)
        retrieve_results = hybrid_retrieve_hyde(hypothesis,query,k_vec=k,k_bm25=max(30, 3 * k),top_n=k,)
    else:
        retrieve_results = hybrid_retrieve(query,k_vec=k,k_bm25=max(30, 3 * k),top_n=k,)

    results = rerank(query, retrieve_results)

    # contexts for RAGAS
    contexts = [doc.page_content for doc, _ in results]
    return contexts

# %% [markdown]
# #### 4.2 Prepare dataset

# %%
from tqdm import tqdm

eval_questions = [
    "Which players received the most yellow cards for West Ham in the 2016 season?",
    "Analyze the playing style and on-pitch role of Cheikhou Kouyaté for West Ham during the 2016 season.",
    "Compare the disciplinary records and defensive aggression of Aston Villa and West Ham in the 2016 season, identifying key players involved in these actions.",
    "Who contributed most to West Ham's defensive solidity in the 2016 season, and how did their performances impact the team's overall defensive record?",
    "Who contributed the most to West Ham's attacking play in the 2016 season, and what were their key statistics?"
    "Compare the defensive aggression of Liverpool and Everton in the 2016 season, focusing on players with the highest tackle and foul counts."
    "Which Manchester United defenders committed the most fouls in the 2016 season, and what does this indicate about their defensive style?"
    "How did Kevin De Bruyne’s positional play influence his team's chance creation in the 2016 season, and which metrics best reflect his impact?"
    "Which team showed stronger defensive consistency in the 2016 season—Southampton or Everton"
    "Compare Crystal Palace and Sunderland in terms of attacking output in the 2016 season. Which players were most responsible for their goal contributions?"
    "Compare the playing styles of Mesut Ozil and Philippe Coutinho in the 2015 season. How did each contribute to their team's attacking patterns?"
    "Which Tottenham midfielder played the most crucial role in linking defense to attack during the 2016 season, and what data supports this analysis?"
]

answers = []
contexts_list = []

for q in tqdm(eval_questions, desc="Evaluating RAG"):
    ans = answer_with_llm(q, k=12, use_history=False, use_hyde=True)
    ctxs = retrieve_for_eval(q, k=12, use_hyde=True)
    answers.append(ans)
    contexts_list.append(ctxs)
# Out:
# Evaluating RAG: 100%|██████████| 5/5 [07:21<00:00, 88.33s/it]

# %%
# !pip install datasets

from datasets import Dataset

dataset = Dataset.from_dict(
    {
        "question": eval_questions,
        "answer": answers,
        "contexts": contexts_list,   # list[list[str]]
    }
)

# %%
import json

data = {
    "questions": eval_questions,
    "answers": answers,
    "contexts": contexts_list,   # list[list[str]]
}

with open("rag_eval_data.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)
